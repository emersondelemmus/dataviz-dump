# %% [markdown]
# ## Identifying and Visualizing missing Data

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: scipy in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from missingno) (1.9.0)
# Requirement already satisfied: seaborn in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from missingno) (0.12.0rc0)
# Requirement already satisfied: numpy in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from missingno) (1.23.2)
# Requirement already satisfied: matplotlib in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from missingno) (3.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->missingno) (4.35.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from seaborn->missingno) (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\edelemmus\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.1
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('POST_2000_TEST_Aluminum_Powder_wUnqNum.csv')

# %%
df.describe()
# Out:
#        TIME_PASSED      MASS_LBS  PURITY_GC_VENDOR  FREE_ALUMINUM_VENDOR  \
# count    26.000000     58.000000      7.000000e+00             47.000000
# mean   1643.576923   1910.931034      9.980000e+01             98.344681
# std    1334.783134   1981.791807      1.534948e-14              0.236651
# min      18.000000      1.000000      9.980000e+01             97.700000
# 25%      38.000000    838.750000      9.980000e+01             98.200000
# 50%    1846.500000   1350.000000      9.980000e+01             98.400000
# 75%    2428.000000   2167.500000      9.980000e+01             98.500000
# max    4186.000000  10800.000000      9.980000e+01             98.900000
#
#        FREE_ALUMINUM_ABL  VOLATILE_CONTENT  IRON_%_VENDOR  OIL_GREASE_%  \
# count           7.000000         59.000000      57.000000  5.700000e+01
# mean           98.219000          0.048814       0.098772  1.000000e-02
# std             1.848439          0.014513       0.012546  1.750144e-18
# min            95.000000          0.020000       0.070000  1.000000e-02
# 25%            97.925000          0.040000       0.090000  1.000000e-02
# 50%            98.033000          0.050000       0.100000  1.000000e-02
# 75%            98.675000          0.055000       0.110000  1.000000e-02
# max           101.300000          0.080000       0.130000  1.000000e-02
#
#        PASS_45_325_FILTER  APS_Fisher  PARTICLE_SIZE_VENDOR_.10  \
# count           59.000000   51.000000                 42.000000
# mean            99.898305    3.370588                  2.073810
# std              0.013019    0.181432                  0.146603
# min             99.800000    3.000000                  1.500000
# 25%             99.900000    3.300000                  2.000000
# 50%             99.900000    3.300000                  2.100000
# 75%             99.900000    3.400000                  2.175000
# max             99.900000    3.900000                  2.300000
#
#        PARTICLE_SIZE_VENDOR_.50  PARTICLE_SIZE_ABL_.50  \
# count                 42.000000              11.000000
# mean                   4.511905               4.754545
# std                    0.258704               0.262159
# min                    3.900000               4.300000
# 25%                    4.400000               4.550000
# 50%                    4.500000               4.800000
# 75%                    4.675000               5.000000
# max                    5.200000               5.000000
#
#        PARTICLE_SIZE_VENDOR_.90  PARTICLE_SIZE_ABL_.90
# count                 42.000000              11.000000
# mean                  10.166667              10.636364
# std                    0.378487               0.529665
# min                    9.500000               9.900000
# 25%                    9.900000              10.250000
# 50%                   10.200000              10.600000
# 75%                   10.400000              10.900000
# max                   11.100000              11.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ABL_LOT_NUM               60 non-null     object
#  1   UNIQUE_NUM                15 non-null     object
#  2   DATE_SOLD                 59 non-null     object
#  3   TEST_DATE                 30 non-null     object
#  4   TIME_PASSED               26 non-null     float64
#  5   MASS_LBS                  58 non-null     float64
#  6   PURITY_GC_VENDOR          7 non-null      float64
#  7   TOTAL_ALUMINUM_VENDOR     29 non-null     object
#  8   FREE_ALUMINUM_VENDOR      47 non-null     float64
#  9   FREE_ALUMINUM_ABL         7 non-null      float64
#  10  VOLATILE_CONTENT          59 non-null     float64
#  11  IRON_%_VENDOR             57 non-null     float64
#  12  OIL_GREASE_%              57 non-null     float64
#  13  PASS_45_325_FILTER        59 non-null     float64
#  14  APS_Fisher                51 non-null     float64
#  15  PARTICLE_SIZE_VENDOR_.10  42 non-null     float64
#  16  PARTICLE_SIZE_ABL_.10     14 non-null     object
#  17  PARTICLE_SIZE_VENDOR_.50  42 non-null     float64
#  18  PARTICLE_SIZE_ABL_.50     11 non-null     float64
#  19  PARTICLE_SIZE_VENDOR_.90  42 non-null     float64
#  20  PARTICLE_SIZE_ABL_.90     11 non-null     float64
# dtypes: float64(15), object(6)
# memory usage: 10.0+ KB

# %%
df.isna().sum()
# Out:
# ABL_LOT_NUM                  0
# UNIQUE_NUM                  45
# DATE_SOLD                    1
# TEST_DATE                   30
# TIME_PASSED                 34
# MASS_LBS                     2
# PURITY_GC_VENDOR            53
# TOTAL_ALUMINUM_VENDOR       31
# FREE_ALUMINUM_VENDOR        13
# FREE_ALUMINUM_ABL           53
# VOLATILE_CONTENT             1
# IRON_%_VENDOR                3
# OIL_GREASE_%                 3
# PASS_45_325_FILTER           1
# APS_Fisher                   9
# PARTICLE_SIZE_VENDOR_.10    18
# PARTICLE_SIZE_ABL_.10       46
# PARTICLE_SIZE_VENDOR_.50    18
# PARTICLE_SIZE_ABL_.50       49
# PARTICLE_SIZE_VENDOR_.90    18
# PARTICLE_SIZE_ABL_.90       49
# dtype: int64

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# Create one scatter plot for each .csv file in the current directory and save it as a png file
import os
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno

# Loop through all files in the current directory ending with .csv
for file in os.listdir():
    if file.endswith("_wUnqNum.csv"):
        # Read the csv file into a pandas DataFrame
        df = pd.read_csv(file, encoding='latin1')

        # Create a scatter plot of the data
        plt.figure(figsize=(20, 10))
        msno.matrix(df)
        # Save the plot as a png file
        #plt.tight_layout()
        plt.savefig(file.replace('.csv', '.png'),  bbox_inches="tight", dpi=300)

        # Close the plot so it doesn't show up in the UI
        plt.close()
